# %% [markdown]
# <a href="https://colab.research.google.com/github/alanazip/Python-2-modulo/blob/main/Alana_Souza_211_P2_LP_m.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##**P2 - 1º. semestre/2021 -   Início: 7:40   -    Término: 10:40**
# ## É uma prova de consulta ao seu material.
# ## **Apenas verificarei** o desenvolvimento dos exercícios de cada aluno, **NO DIA SEGUINTE**
# ##Se precisar, apenas **escreva no chat privado**

# %% [markdown]
# ###**1.** Em Python crie um programa que atenda o menu a seguir. Desenvolva uma função para cada opção do menu. Utilize criação de estrutura. Cadastrar 5 (vetor) alunos ( Tipo_Aluno: ra (str), nome(str), p1(float), p2(float), media(float), endereco (Tipo_Endereco: rua(str), numero(int) )
#
# Menu de opções:
#
# 1 Cadastrar alunos
#
# 2 Calcular média de um aluno por ra
#
# 3 Calcular média de todos os alunos
#
# 4 Visualizar todos os alunos dados
#
# 5 Armazenar todos os campos em um arquivo
#
# 6 Apresentar o conteúdo do arquivo
#
# 7 Sair
#
#
# **Observaçôes**:
#
# * ra (registro acadêmico).
#
# * Na opção 1, todo ra deve começar com o caracter ‘1’, para isso verifique o conteúdo digitado antes de inserir na estrutura, crie uma função para isso. Não deve ser calculada a média.
#
# * Na opção 2, o usuário do sistema deverá informar para qual ra será calculada a média, lembre de verificar o ra, para isso volte a utilizar a chamada da função que atendeu a opção 1.
#
# * Na opção 5 e 6 o nome do arquivo deverá ser aluno.txt

# %%
class complemento:
  rua = ''
  numero = 0
class aluno:
  ra = ''
  nome = ''
  p1 = 0.0
  p2 = 0.0
  media = 0.0
  endereco = complemento()
def cadastrar():
  vet_cadastrar=[]
  arquivo = open('aluno.txt','w')
  for i in range(5):
    a = aluno()
    a.ra = input('informe seu RA iniciado em 1: ')
    a.nome = input('informe seu nome: ')
    a.p1 = float(input('informe sua nota p1: '))
    a.p2 = float(input('informe sua nota p2: '))
    a.endereco.rua = input('informe sua rua: ')
    a.endereco.numero = int(input('N°: '))
    vet_cadastrar.append(a)
    arquivo.write(f'{a.ra},{a.nome},{a.p1:.2f},{a.p2:.2f},{a.endereco.rua},{a.endereco.numero}\n')
  arquivo.close()
  return vet_cadastrar
def media_ra(vet_cadastrar):
  pesq = input('Insira o RA do aluno para calcular a média: ')
  achei = False
  i = 0
  for i in range(len(vet_cadastrar)):
    if pesq == vet_cadastrar[i].ra:
      achei = True
      if achei == True:
        print('RA encontrado.')
        media = (vet_cadastrar[i].p1 + vet_cadastrar[i].p2 ) / 2
        print('media: ',media)
      else:
        print('RA não encontrado.')
def media(vet_cadastrar):
  i = 0
  for i in range(len(vet_cadastrar)):
    media = (vet_cadastrar[i].p1 + vet_cadastrar[i].p2) / 2
    raa = vet_cadastrar[i].ra
    print('RA: ',raa,'media: ',media)
def visualizar(vet_cadastrar):
  for i in range(len(vet_cadastrar)):
    print('Nome:',vet_cadastrar[i].nome,'\tRA:',vet_cadastrar[i].ra,'\tNota - P1:',vet_cadastrar[i].p1,'\tNota - P2:',vet_cadastrar[i].p2,'\tRua:',vet_cadastrar[i].endereco.rua, '\tNúmero:',vet_cadastrar[i].endereco.numero)
def armazenar(vet_cadastrar):
  arquivo = open('aluno.txt','w')
  print('Armazenado com sucesso!')
  arquivo.write(str(vet_cadastrar))
  arquivo.close
def apresentar_arq(vet_cadastrar):
  arquivo = open('aluno.txt', 'r')
  print('')
  print('Apresentação dos dados do arquivo.')
  print('')
  for linha in arquivo.readlines():
    ra,nome,p1,p2,rua,numero = linha.strip().split(",") 
    print('ra \t nome \t p1 \t p2 \t rua \t numero')
    print(ra,'\t\t',nome,'\t\t',p1,'\t\t',p2,'\t\t',rua,'\t\t',numero)
  arquivo.close
def main():
  op = 1
  while op >= 1 and op <= 7:
    print('MENU DE OPÇÕES')
    print('Cadastrar aluno digite 1')
    print('Calcular média de um aluno por RA digite 2')
    print('Calcular média de todos os alunos digite 3')
    print('Visualizar todos os alunos dados digite 4')
    print('Armazenar todos os campos em um arquivo digite 5')
    print('Apresentar o conteúdo do arquivo digite 6')
    print('Para sair digite 7')
    op=int(input('Digite a opção desejada: '))
    if op == 1:
      vet_a = cadastrar()
    elif op == 2:
      media_ra(vet_a)
    elif op == 3:
      media(vet_a)
    elif op == 4:
      visualizar(vet_a)
    elif op == 5:
      armazenar(vet_a)
    elif op == 6:
      apresentar_arq(vet_a)
    elif op == 7:
      break
main()
# Out:
# MENU DE OPÇÕES
# Cadastrar aluno digite 1
# Calcular média de um aluno por RA digite 2
# Calcular média de todos os alunos digite 3
# Visualizar todos os alunos dados digite 4
# Armazenar todos os campos em um arquivo digite 5
# Apresentar o conteúdo do arquivo digite 6
# Para sair digite 7
# Digite a opção desejada: 1
# informe seu RA iniciado em 1: 12345
# informe seu nome: Alana
# informe sua nota p1: 9
# informe sua nota p2: 10
# informe sua rua: Catharino
# N°: 45
# informe seu RA iniciado em 1: 15576
# informe seu nome: Cesar
# informe sua nota p1: 7
# informe sua nota p2: 8
# informe sua rua: Pereira
# N°: 13
# informe seu RA iniciado em 1: 12232
# informe seu nome: Felipe
# informe sua nota p1: 8
# informe sua nota p2: 10
# informe sua rua: Terminal
# N°: 101
# informe seu RA iniciado em 1: 12323
# informe seu nome: Yuri
# informe sua nota p1: 4
# informe sua nota p2: 5
# informe sua rua: Professor
# N°: 675
# informe seu RA iniciado em 1: 12152
# informe seu nome: Anderson
# ...
